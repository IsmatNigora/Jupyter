# %% [markdown]
# ### 1、please import pandas

# %%
import pandas as pd

# %% [markdown]
# ### 2、please read the Breast_cancer_data_for_ML.csv file and saved as DataFrame and name it as 'data'.

# %%
#df = pd.read_csv(r'Breast_cancer_data_for_ML.csv') # 33 - лишняя нумерация
df = pd.read_csv("Breast_cancer_data_for_ML.csv", index_col = 'id') #32
df
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
# ...            ...          ...           ...             ...        ...
# 926424           M        21.56         22.39          142.00     1479.0
# 926682           M        20.13         28.25          131.20     1261.0
# 926954           M        16.60         28.08          108.30      858.1
# 927241           M        20.60         29.33          140.10     1265.0
# 92751            B         7.76         24.54           47.92      181.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# ...

# %% [markdown]
# ### 3、please drop the 'Unnamed: 32' column

# %%
#df.drop(['Unnamed: 32'], axis='columns') -это оставляло
df.drop(['Unnamed: 32'],axis = 'columns' ,inplace = True)

# %% [markdown]
# ### 4、please to use 1,0 instead of 'M' and 'B'

# %%
#df.loc[df['diagnosis'] == 'M', 'diagnosis'] = 1
#df.loc[df['diagnosis'] == 'B', 'diagnosis'] = 0

df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B':0})
df
# Out:
#           diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302            1        17.99         10.38          122.80     1001.0
# 842517            1        20.57         17.77          132.90     1326.0
# 84300903          1        19.69         21.25          130.00     1203.0
# 84348301          1        11.42         20.38           77.58      386.1
# 84358402          1        20.29         14.34          135.10     1297.0
# ...             ...          ...           ...             ...        ...
# 926424            1        21.56         22.39          142.00     1479.0
# 926682            1        20.13         28.25          131.20     1261.0
# 926954            1        16.60         28.08          108.30      858.1
# 927241            1        20.60         29.33          140.10     1265.0
# 92751             0         7.76         24.54           47.92      181.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# ...

# %% [markdown]
# ### 5、please split the data into training data and test data

# %%
from sklearn.model_selection import train_test_split
y = df['diagnosis']
#y_train, y_test = train_test_split( y, test_size=0.3)

X=df.drop('diagnosis',axis = 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

# %% [markdown]
# ### 6、please do data preprocesing

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn import decomposition
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import sklearn

# %%
from sklearn.preprocessing import StandardScaler
X_scaled = StandardScaler().fit_transform(X)
pca = decomposition.PCA(n_components=2)

X_pca_scaled = pca.fit_transform(X_scaled)

print('Projecting %d-dimensional data to 2D' % X_scaled.shape[1])
# Out:
# Projecting 30-dimensional data to 2D

# %% [markdown]
# ### 7、please use SVM to do classification

# %%
from sklearn.svm import SVC
name_model=SVC()

# %%
from sklearn.svm import SVC
SVM_model = SVC(
    C=1.0,
    kernel='rbf',
    degree=3,
    gamma='auto_deprecated',
    coef0=0.0,
    shrinking=True,
    probability=False,
    tol=0.001,
    cache_size=200,
    class_weight=None,
    verbose=False,
    max_iter=-1,
    decision_function_shape='ovr',
    random_state=None,
)
SVM_model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c327265e3545> in <module>
#      16     random_state=None,
#      17 )
# ---> 18 SVM_model.fit(X_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     183                 raise ValueError(
#     184                     "When 'gamma' is a string, it should be either 'scale' or "
# --> 185                     "'auto'. Got '{}' instead.".format(self.gamma)
#     186                 )
#     187         else:
#
# ValueError: When 'gamma' is a string, it should be either 'scale' or 'auto'. Got 'auto_deprecated' instead.

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score
svm_pred = SVM_model.predict(X_holdout)
print ("Accuracy Score : ",accuracy_score(y_holdout, svm_pred) )
print ("Recall Score (how much of malignant tumours were predicted correctly) : ",recall_score(y_holdout, svm_pred))
print ("Precision Score (how much of tumours, which were predicted as 'malignant', were actually 'malignant'): ",precision_score(y_holdout, svm_pred))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-30-8a1254e9603d> in <module>
#       1 from sklearn.metrics import accuracy_score, recall_score, precision_score
# ----> 2 svm_pred = SVM_model.predict(X_holdout)
#       3 print ("Accuracy Score : ",accuracy_score(y_holdout, svm_pred) )
#       4 print ("Recall Score (how much of malignant tumours were predicted correctly) : ",recall_score(y_holdout, svm_pred))
#       5 print ("Precision Score (how much of tumours, which were predicted as 'malignant', were actually 'malignant'): ",precision_score(y_holdout, svm_pred))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py in predict(self, X)
#     582             Class labels for samples in X.
#     583         """
# --> 584         check_is_fitted(self)
#     585         if self.break_ties and self.decision_function_shape == 'ovo':
# ...
